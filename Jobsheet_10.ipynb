# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2025_Algoritma_Pemrograman/blob/main/Jobsheet_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 - Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# #Praktikum 02 - Selection Sort

# %%
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# #Praktikum 03 - Insertion Sort

# %%
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]

# %% [markdown]
# #Praktikum 04 - Studi Kasus Nilai Mahasiswa

# %%
def bubble_sort_nilai(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j][1] < data[j + 1][1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

mahasiswa = [("Andi", 80), ("Budi", 70), ("Cici", 90), ("Doni", 85)]
print("Data sebelum diurutkan:", mahasiswa)
print("Data setelah diurutkan (desc):", bubble_sort_nilai(mahasiswa))
# Out:
# Data sebelum diurutkan: [('Andi', 80), ('Budi', 70), ('Cici', 90), ('Doni', 85)]
# Data setelah diurutkan (desc): [('Cici', 90), ('Doni', 85), ('Andi', 80), ('Budi', 70)]

# %% [markdown]
# #Praktikum 05 - Perbandingan Waktu Eksekusi

# %%
# %%writefile bubble.py

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data
# Out:
# Writing bubble.py

# %%
# %%writefile selection.py
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data
# Out:
# Writing selection.py

# %%
# %%writefile insertion.py
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data
# Out:
# Writing insertion.py

# %%
import random, time

from bubble import bubble_sort
from selection import selection_sort
from insertion import insertion_sort

data = [random.randint(1,1000) for i in range(500)]

for func in [bubble_sort, selection_sort, insertion_sort]:
  salinan = data.copy()
  start = time.time()
  func(salinan)
  end = time.time()
  print(f"{func.__name__} membutuhkan waktu {end - start:.5f} detik")
# Out:
# bubble_sort membutuhkan waktu 0.02209 detik
# selection_sort membutuhkan waktu 0.01114 detik
# insertion_sort membutuhkan waktu 0.01043 detik

# %% [markdown]
# #Praktikum 06 - Sorting Data Barang

# %%
def bubble_sort_key(data, key_index = 0, reverse = False):
  n = len(data)
  for i in range (n):
    for j in range (0, n - i - 1):
      if reverse:
        if data[j][key_index] < data[j + 1][key_index]:
          data[j], data[j + 1] = data[j + 1], data[j]
      else:
          if data[j][key_index] > data[j + 1][key_index]:
            data[j], data[j + 1] = data[j + 1], data[j]
  return data

barang = [("Buku", 15000), ("Pensil", 5000), ("Tas", 75000), ("Pulpen", 10000)]
print("Urut berdasarkan nama (asc):", bubble_sort_key(barang.copy(), 0))
print("Urut berdasarkan harga (desc):", bubble_sort_key(barang.copy(), 1, reverse=True))
# Out:
# Urut berdasarkan nama (asc): [('Buku', 15000), ('Pensil', 5000), ('Pulpen', 10000), ('Tas', 75000)]
# Urut berdasarkan harga (desc): [('Tas', 75000), ('Buku', 15000), ('Pulpen', 10000), ('Pensil', 5000)]

# %% [markdown]
# #Penugasan 01 - Eksperimen Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] < data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort (Descending): ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort (Descending):  [90, 64, 34, 25, 22, 12, 11]

# %% [markdown]
# #Penugasan 02 - Eksperimen Selection Sort

# %%
def selection_sort_elemen_terbesar(data):
  n = len(data)
  for i in range(n - 1, 0, -1):
    max_index = 0
    for j in range(1, i + 1):
      if data[j] > data[max_index]:
        max_index = j
    data[i], data[max_index] = data[max_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort (elemen terbesar ke akhir):", selection_sort_elemen_terbesar(angka))
# Out:
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort (elemen terbesar ke akhir): [11, 12, 22, 25, 64]

# %% [markdown]
# #Penugasan 03 - Eksperimen Insertion Sort

# %%
def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data


mahasiswa = []
pilihan = int(input("Ketik 1 untuk memulai: "))

while pilihan == 1:
    nama = input(f"Masukkan nama mahasiswa: ")
    pilihan = int(input("ketik 1 untuk lanjut: "))
    mahasiswa.append(nama)

print(f"\nData sebelum diurutkan: {mahasiswa}")

hasil = insertion_sort(mahasiswa)

print(f"\nData setelah diurutkan menggunakan Insertion Sort (A - Z): {hasil}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1919504764.py in <cell line: 0>()
#      11
#      12 mahasiswa = []
# ---> 13 pilihan = int(input("Ketik 1 untuk memulai: "))
#      14
#      15 while pilihan == 1:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# #Penugasan 04 - Studi Kasus Tambahan

# %%
# %%writefile nilai.py

def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data

# %%
from nilai import insertion_sort

mahasiswa = ["Faiq", "Agus", "Bagus", "Budi", "Jono"]

insertion_sort(mahasiswa)

# %% [markdown]
# #Penugasan 05 - Analisis Kompleksitas

# %%
import time, random

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data


def jalankan_pengujian(ukuran):
    for i in ukuran:
      data = [random.randint(1,1000) for i in range(i)]
      print(f"\n=== Ukuran data: {i} ===")
      print(data)
      for func in [bubble_sort, selection_sort, insertion_sort]:
          data = data.copy()
          start = time.time()
          end = time.time()
          print(f"{func.__name__} membutuhkan waktu {end - start:.10f} detik")

ukuran = [10, 50, 100]
jalankan_pengujian(ukuran)
# Out:
# === Ukuran data: 10 ===
# [150, 4, 882, 646, 335, 665, 639, 78, 577, 515]
# bubble_sort membutuhkan waktu 0.0000007153 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000002384 detik
#
# === Ukuran data: 50 ===
# [869, 531, 17, 27, 820, 695, 600, 156, 656, 287, 36, 853, 45, 320, 537, 242, 314, 946, 616, 482, 34, 652, 894, 425, 914, 405, 586, 168, 814, 380, 413, 508, 557, 806, 119, 622, 325, 684, 620, 331, 5, 49, 12, 807, 910, 252, 328, 403, 659, 338]
# bubble_sort membutuhkan waktu 0.0000004768 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000000000 detik
#
# === Ukuran data: 100 ===
# [143, 857, 643, 94, 753, 548, 653, 500, 868, 793, 757, 527, 463, 466, 448, 684, 939, 727, 431, 343, 844, 477, 426, 825, 427, 621, 447, 884, 899, 739, 251, 512, 312, 390, 3, 194, 163, 445, 962, 46, 245, 116, 167, 930, 55, 84, 791, 480, 831, 57, 18, 583, 579, 274, 994, 462, 450, 967, 34, 886, 436, 399, 99, 12, 642, 839, 370, 721, 344, 313, 297, 97, 92, 506, 513, 154, 873, 69, 517, 789, 844, 296, 854, 737, 188, 993, 930, 636, 121, 226, 677, 19, 938, 815, 462, 530, 993, 425, 636, 990]
# bubble_sort membutuhkan waktu 0.0000004768 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000000000 detik

# %% [markdown]
# #Penugasan 06 - Proyek Mini

# %%
# %%writefile sort.py

def bubble_sort(data, key_index, reverse=False):
  n = len(data)
  data = data.lower()
  for i in range (n):
    for j in range (0, n - i - 1):
      if reverse:
        if data[j][key_index] < data[j + 1][key_index]:
          data[j], data[j + 1] = data[j + 1], data[j]
      else:
          if data[j][key_index] > data[j + 1][key_index]:
            data[j], data[j + 1] = data[j + 1], data[j]
  return data
# Out:
# Overwriting sort.py

# %%
from sort import bubble_sort

barang = []
pilihan = int(input("Masukkan 1 untuk menambah barang: "))

while pilihan == 1:
    nama = input("Masukkan nama barang: ")
    harga = int(input("Masukkan harga barang: "))
    barang.append([nama, harga])
    pilihan = int(input("Masukkan 1 untuk menambah barang lagi: "))

print("\n1. Urut berdasarkan nama")
print("2. Urut berdasarkan harga")
key_index = int(input("Pilih (1/2): ")) - 1

print("\n1. Ascending")
print("2. Descending")
pilihan = int(input("Pilih (1/2): "))
if pilihan == 1:
  hasil = bubble_sort(barang, key_index)
else:
  hasil = bubble_sort(barang, key_index, reverse = True)

print("\nHasil pengurutan:")
print(hasil)
# Out:
# Masukkan 1 untuk menambah barang: 1
# Masukkan nama barang: Faiz
# Masukkan harga barang: 1230718
# Masukkan 1 untuk menambah barang lagi: 1
# Masukkan nama barang: faiq
# Masukkan harga barang: 1029639
# Masukkan 1 untuk menambah barang lagi: 2
#
# 1. Urut berdasarkan nama
# 2. Urut berdasarkan harga
# Pilih (1/2): 1
#
# 1. Ascending
# 2. Descending
# Pilih (1/2): 1
#
# Hasil pengurutan:
# [['Faiz', 1230718], ['faiq', 1029639]]
