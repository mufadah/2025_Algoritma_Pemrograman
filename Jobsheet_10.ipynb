# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2025_Algoritma_Pemrograman/blob/main/Jobsheet_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 - Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# #Praktikum 02 - Selection Sort

# %%
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# #Praktikum 03 - Insertion Sort

# %%
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]

# %% [markdown]
# #Praktikum 04 - Studi Kasus Nilai Mahasiswa

# %%
def bubble_sort_nilai(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j][1] < data[j + 1][1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

mahasiswa = [("Andi", 80), ("Budi", 70), ("Cici", 90), ("Doni", 85)]
print("Data sebelum diurutkan:", mahasiswa)
print("Data setelah diurutkan (desc):", bubble_sort_nilai(mahasiswa))
# Out:
# Data sebelum diurutkan: [('Andi', 80), ('Budi', 70), ('Cici', 90), ('Doni', 85)]
# Data setelah diurutkan (desc): [('Cici', 90), ('Doni', 85), ('Andi', 80), ('Budi', 70)]

# %% [markdown]
# #Praktikum 05 - Perbandingan Waktu Eksekusi

# %%
# %%writefile bubble.py

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Writing bubble.py

# %%
# %%writefile selection.py
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Writing selection.py

# %%
# %%writefile insertion.py
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Writing insertion.py

# %%
import random, time

from bubble import bubble_sort
from selection import selection_sort
from insertion import insertion_sort

data = [random.randint(1,1000) for i in range(500)]

for func in [bubble_sort, selection_sort, insertion_sort]:
  salinan = data.copy()
  start = time.time()
  func(salinan)
  end = time.time()
  print(f"{func.__name__} membutuhkan waktu {end - start:.5f} detik")
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]
# bubble_sort membutuhkan waktu 0.00874 detik
# selection_sort membutuhkan waktu 0.00401 detik
# insertion_sort membutuhkan waktu 0.00342 detik

# %% [markdown]
# #Praktikum 06 - Sorting Data Barang

# %%
def bubble_sort_key(data, key_index = 0, reverse = False):
  n = len(data)
  for i in range (n):
    for j in range (0, n - i - 1):
      if reverse:
        if data[j][key_index] < data[j + 1][key_index]:
          data[j], data[j + 1] = data[j + 1], data[j]
  return data

barang = [("Buku", 15000), ("Pensil", 5000), ("Tas", 75000), ("Pulpen", 10000)]
print("Urut berdasarkan nama (asc):", bubble_sort_key(barang.copy(), 0))
print("Urut berdasarkan harga (desc):", bubble_sort_key(barang.copy(), 1, reverse=True))
# Out:
# Urut berdasarkan nama (asc): [('Buku', 15000), ('Pensil', 5000), ('Tas', 75000), ('Pulpen', 10000)]
# Urut berdasarkan harga (desc): [('Tas', 75000), ('Buku', 15000), ('Pulpen', 10000), ('Pensil', 5000)]

# %% [markdown]
# #Penugasan 01 - Eksperimen Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] < data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort (Descending): ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort (Descending):  [90, 64, 34, 25, 22, 12, 11]

# %% [markdown]
# #Penugasan 02 - Eksperimen Selection Sort

# %%
def selection_sort_elemen_terbesar(data):
  n = len(data)
  for i in range(n - 1, 0, -1):
    max_index = 0
    # print()
    # print("ya", data[i])
    for j in range(1, i + 1):
      # print(j)
      if data[j] > data[max_index]:
        # print(data[j], "Dibanding", data[max_index])
        max_index = j
        # print("ini", max_index)
      data[i], data[max_index] = data[max_index], data[i]
      # print("Kalo", data[i], data[max_index])
      # print(data)
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort (elemen terbesar ke akhir):", selection_sort_elemen_terbesar(angka))
# Out:
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort (elemen terbesar ke akhir): [11, 12, 22, 25, 64]

# %% [markdown]
# #Penugasan 03 - Eksperimen Insertion Sort

# %%
def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data


mahasiswa = []
pilihan = int(input("Ketik 1 untuk memulai: "))

while pilihan == 1:
    nama = input(f"Masukkan nama mahasiswa: ")
    pilihan = int(input("ketik 1 untuk lanjut: "))
    mahasiswa.append(nama)

print(f"\nData sebelum diurutkan: {mahasiswa}")

hasil = insertion_sort(mahasiswa)

print(f"\nData setelah diurutkan menggunakan Insertion Sort (A - Z): {hasil}")

# %% [markdown]
# #Penugasan 04 - Studi Kasus Tambahan

# %%
# %%writefile nilai.py

def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data

# %%
from nilai import insertion_sort

mahasiswa = ["Faiq", "Agus", "Bagus", "Budi", "Jono"]

insertion_sort(mahasiswa)

# %% [markdown]
# #Penugasan 05 - Analisis Kompleksitas

# %%
import time, random

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

def jalankan_pengujian(ukuran):
    data = [random.randint(1,1000) for i in range(ukuran)]
    print(f"\n=== Ukuran data: {ukuran} ===")
    print(data)
    for func in [bubble_sort, selection_sort, insertion_sort]:
        data = data.copy()
        start = time.time()
        end = time.time()
        print(f"{func.__name__} membutuhkan waktu {end - start:.10f} detik")

for ukuran in [10, 50, 100]:
    jalankan_pengujian(ukuran)

# %% [markdown]
# #Penugasan 06 - Proyek Mini

# %%
# %%writefile descending.py

def insertion_sort(data, key_index = 0):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j][key_index] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

# %%
from insertion import insertion_sort
from descending import insertion_sort as reverse

pilihan = int(input("Masukkan 1 untuk lanjut: ")).strip()
data = []

while pilihan == 1:
  nama = input("Masukkan nama barang: ")
  harga = int(input("Masukkan harga barang: "))
  data.append([nama, harga])
  pilihan = int(input("ketik 1 untuk lanjut: "))

# print("1. Urut sesuai nama")
# print("2. Urut sesuai harga")
# urutan = int(input("Masukkan angka: "))
# print("1. Ascending")
# print("2. Descending")
print(insertion_sort(data))

# %% [markdown]
# BAWAH ITU BELUM JADI !!!

# %%
def input_items():
    items = []
    while True:
        nama = input("Masukkan nama barang (kosongkan untuk selesai): ").strip()
        if not nama:
            break
        while True:
            harga = input("Masukkan harga (angka): ").strip()
            try:
                harga_val = float(harga)
                break
            except ValueError:
                print("Harga tidak valid. Masukkan angka, misalnya 15000 atau 99.99.")
        items.append({"name": nama, "price": harga_val})
    return items

def display_items(items):
    if not items:
        print("(Tidak ada data barang)\n")
        return
    print("\nDaftar barang:")
    print(f"{'No':<4}{'Nama':<30}{'Harga':>12}")
    print("-" * 46)
    for i, it in enumerate(items, start=1):
        print(f"{i:<4}{it['name']:<30}{it['price']:>12.2f}")
    print()

def sort_items(items, by="name", ascending=True):
    if by == "name":
        keyfunc = lambda it: it["name"].casefold()
    else:
        keyfunc = lambda it: it["price"]
    return sorted(items, key=keyfunc, reverse=not ascending)

def main():
    print("=== Program Manajemen Barang Sederhana ===")
    items = input_items()
    while True:
        print("Pilih aksi:")
        print("1. Tampilkan daftar barang")
        print("2. Urutkan barang")
        print("3. Tambah barang")
        print("4. Keluar")
        pilihan = input("Masukkan pilihan (1-4): ").strip()

        if pilihan == "1":
            display_items(items)

        elif pilihan == "2":
            if not items:
                print("Tidak ada barang untuk diurutkan.\n")
                continue
            print("Urutkan berdasarkan:")
            print("a. Nama (A-Z / Z-A)")
            print("b. Harga (Naik / Turun)")
            opsi = input("Pilih (a/b): ").strip().lower()
            if opsi == "a":
                arah = input("Ascending (A) atau Descending (D)? ").strip().lower()
                asc = True if arah == "a" or arah == "ascending" else False
                items = sort_items(items, by="name", ascending=asc)
                display_items(items)
            elif opsi == "b":
                arah = input("Ascending (Naik) (A) atau Descending (Turun) (D)? ").strip().lower()
                asc = True if arah == "a" or arah == "ascending" else False
                items = sort_items(items, by="price", ascending=asc)
                display_items(items)
            else:
                print("Pilihan tidak valid.\n")

        elif pilihan == "3":
            new_items = input_items()
            items.extend(new_items)
            print("Barang berhasil ditambahkan.\n")

        elif pilihan == "4":
            print("Keluar. Terima kasih.")
            break

        else:
            print("Pilihan tidak dikenal. Coba lagi.\n")

if __name__ == "__main__":
    main()
