# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2025_Algoritma_Pemrograman/blob/main/Jobsheet_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 - Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# #Praktikum 02 - Selection Sort

# %%
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))

# %% [markdown]
# #Praktikum 03 - Insertion Sort

# %%
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]

# %% [markdown]
# #Praktikum 04 - Studi Kasus Nilai Mahasiswa

# %%
def bubble_sort_nilai(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j][1] < data[j + 1][1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

mahasiswa = [("Andi", 80), ("Budi", 70), ("Cici", 90), ("Doni", 85)]
print("Data sebelum diurutkan:", mahasiswa)
print("Data setelah diurutkan (desc):", bubble_sort_nilai(mahasiswa))
# Out:
# Data sebelum diurutkan: [('Andi', 80), ('Budi', 70), ('Cici', 90), ('Doni', 85)]
# Data setelah diurutkan (desc): [('Cici', 90), ('Doni', 85), ('Andi', 80), ('Budi', 70)]

# %% [markdown]
# #Praktikum 05 - Perbandingan Waktu Eksekusi

# %%
# %%writefile bubble.py

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Writing bubble.py

# %%
# %%writefile selection.py
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Writing selection.py

# %%
# %%writefile insertion.py
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Writing insertion.py

# %%
import random, time

from bubble import bubble_sort
from selection import selection_sort
from insertion import insertion_sort

data = [random.randint(1,1000) for i in range(500)]

for func in [bubble_sort, selection_sort, insertion_sort]:
  salinan = data.copy()
  start = time.time()
  func(salinan)
  end = time.time()
  print(f"{func.__name__} membutuhkan waktu {end - start:.5f} detik")
# Out:
# bubble_sort membutuhkan waktu 0.01209 detik
# selection_sort membutuhkan waktu 0.00650 detik
# insertion_sort membutuhkan waktu 0.00678 detik

# %% [markdown]
# #Praktikum 06 - Sorting Data Barang

# %%
def bubble_sort_key(data, key_index = 0, reverse = False):
  n = len(data)
  for i in range (n):
    for j in range (0, n - i - 1):
      if reverse:
        if data[j][key_index] < data[j + 1][key_index]:
          data[j], data[j + 1] = data[j + 1], data[j]
  return data

barang = [("Buku", 15000), ("Pensil", 5000), ("Tas", 75000), ("Pulpen", 10000)]
print("Urut berdasarkan nama (asc):", bubble_sort_key(barang.copy(), 0))
print("Urut berdasarkan harga (desc):", bubble_sort_key(barang.copy(), 1, reverse=True))
# Out:
# Urut berdasarkan nama (asc): [('Buku', 15000), ('Pensil', 5000), ('Tas', 75000), ('Pulpen', 10000)]
# Urut berdasarkan harga (desc): [('Tas', 75000), ('Buku', 15000), ('Pulpen', 10000), ('Pensil', 5000)]

# %% [markdown]
# #Penugasan 01 - Eksperimen Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] < data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort (Descending): ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort (Descending):  [90, 64, 34, 25, 22, 12, 11]

# %% [markdown]
# #Penugasan 02 - Eksperimen Selection Sort

# %%
def selection_sort_elemen_terbesar(data):
  n = len(data)
  for i in range(n - 1, 0, -1):
    max_index = 0
    print()
    print("ya", data[i])
    for j in range(1, i + 1):
      print(j)
      if data[j] > data[max_index]:
        print(data[j], "Dibanding", data[max_index])
        max_index = j
        print("ini", max_index)
      data[i], data[max_index] = data[max_index], data[i]
      print("Kalo", data[i], data[max_index])
      print(data)
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort (elemen terbesar ke akhir):", selection_sort_elemen_terbesar(angka))

# %% [markdown]
# #Penugasan 03 - Eksperimen Insertion Sort

# %%
def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data


mahasiswa = []
pilihan = int(input("Ketik 1 untuk memulai: "))

while pilihan == 1:
    nama = input(f"Masukkan nama mahasiswa: ")
    pilihan = int(input("ketik 1 untuk lanjut: "))
    mahasiswa.append(nama)

print(f"\nData sebelum diurutkan: {mahasiswa}")

hasil = insertion_sort(mahasiswa)

print(f"\nData setelah diurutkan menggunakan Insertion Sort (A - Z): {hasil}")
# Out:
# Ketik 1 untuk memulai: 1
# Masukkan nama mahasiswa: faiq
# ketik 1 untuk lanjut: 1
# Masukkan nama mahasiswa: faiz
# ketik 1 untuk lanjut: 1
# Masukkan nama mahasiswa: faqih
# ketik 1 untuk lanjut: 2
#
# Data sebelum diurutkan: ['faiq', 'faiz', 'faqih']
#
# Data setelah diurutkan menggunakan Insertion Sort (A - Z): ['faiq', 'faiz', 'faqih']

# %% [markdown]
# #Penugasan 04 - Studi Kasus Tambahan

# %%
# %%writefile nilai.py

def insertion_sort(data):
    for i in range(1, len(data)):
        key = data[i]
        j = i - 1
        while j >= 0 and data[j] > key:
            data[j + 1] = data[j]
            j -= 1
        data[j + 1] = key
    return data
# Out:
# Writing nilai.py

# %%
from nilai import insertion_sort

mahasiswa = ["Faiq", "Agus", "Bagus", "Budi", "Jono"]

insertion_sort(mahasiswa)
# Out:
# ['Agus', 'Bagus', 'Budi', 'Faiq', 'Jono']

# %% [markdown]
# #Penugasan 05 - Analisis Kompleksitas

# %%
import time, random

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = i
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

def jalankan_pengujian(ukuran):
    data = [random.randint(1,1000) for i in range(ukuran)]
    print(f"\n=== Ukuran data: {ukuran} ===")
    print(data)
    for func in [bubble_sort, selection_sort, insertion_sort]:
        data = data.copy()
        start = time.time()
        end = time.time()
        print(f"{func.__name__} membutuhkan waktu {end - start:.10f} detik")

for ukuran in [10, 50, 100]:
    jalankan_pengujian(ukuran)
# Out:
# === Ukuran data: 10 ===
# [242, 44, 532, 484, 201, 67, 734, 570, 402, 213]
# bubble_sort membutuhkan waktu 0.0000007153 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000002384 detik
#
# === Ukuran data: 50 ===
# [928, 334, 426, 210, 291, 928, 550, 599, 547, 636, 302, 457, 418, 463, 858, 580, 398, 558, 282, 937, 322, 692, 663, 101, 481, 357, 61, 778, 109, 365, 823, 280, 986, 384, 76, 581, 894, 463, 640, 458, 570, 597, 109, 621, 66, 987, 139, 20, 736, 764]
# bubble_sort membutuhkan waktu 0.0000002384 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000002384 detik
#
# === Ukuran data: 100 ===
# [56, 819, 465, 280, 13, 771, 959, 832, 492, 635, 37, 953, 126, 414, 620, 419, 539, 383, 729, 815, 254, 179, 22, 762, 454, 218, 185, 842, 898, 908, 514, 902, 37, 840, 777, 714, 57, 450, 652, 482, 362, 508, 620, 40, 539, 307, 913, 992, 641, 371, 909, 53, 439, 607, 402, 404, 965, 860, 616, 551, 223, 969, 946, 591, 855, 32, 254, 847, 519, 133, 789, 842, 828, 436, 825, 264, 935, 119, 772, 150, 111, 828, 606, 619, 110, 701, 537, 44, 735, 409, 489, 38, 497, 87, 377, 274, 698, 884, 65, 949]
# bubble_sort membutuhkan waktu 0.0000002384 detik
# selection_sort membutuhkan waktu 0.0000002384 detik
# insertion_sort membutuhkan waktu 0.0000000000 detik

# %% [markdown]
# #Penugasan 06 - Proyek Mini

# %%
# %%writefile descending.py

def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

# %%
from insertion import insertion_sort
from descending import insertion_sort as reverse

pilihan = int(input("Masukkan 1 untuk lanjut: "))
data = []

while pilihan == 1:
  nama = input("Masukkan nama barang: ")
  harga = int(input("Masukkan harga barang: "))
  data.append([nama, harga])
  pilihan = int(input("ketik 1 untuk lanjut: "))

# print("1. Urut sesuai nama")
# print("2. Urut sesuai harga")
# urutan = int(input("Masukkan angka: "))
# print("1. Ascending")
# print("2. Descending")
print(insertion_sort(data))
# Out:
# Masukkan 1 untuk lanjut: 1
# Masukkan nama barang: dasd
# Masukkan harga barang: 1231
# ketik 1 untuk lanjut: 1
# Masukkan nama barang: weqwe
# Masukkan harga barang: 12312
# ketik 1 untuk lanjut: 1
# Masukkan nama barang: 12431ed
# Masukkan harga barang: 123
# ketik 1 untuk lanjut: 3
# [['12431ed', 123], ['dasd', 1231], ['weqwe', 12312]]

# %%
data = [["faiq", 1000], ["tas", 2000], ["jas", 1000]]

print(data[0][1])
# Out:
# 1000
