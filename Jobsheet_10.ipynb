# %% [markdown]
# <a href="https://colab.research.google.com/github/mufadah/2025_Algoritma_Pemrograman/blob/main/Jobsheet_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Praktikum 01 - Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    print ()
    print (f"data1 {data}")
    print (f"i {i}")
    for j in range(0, n - i - 1):
      print (f"j {j}")
      if data[j] > data[j + 1]:
        print (f"Data {data[j]} dan {data[j+1]}")
        data[j], data[j + 1] = data[j + 1], data[j]
        print(data[j],data[j+1])
        print(f"kalo {data[j]}")
        print(f"data +1 {data[j+1]}")
        print(f"data2 {data}")
  return data

angka = [64, 34, 25, 12, 22, 100, 10]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# #Praktikum 02 - Selection Sort

# %%
def selection_sort(data):
  n = len(data)
  for i in range(n):
    print()
    print("Mulai dari",i)
    print("kalo ini data",data[i])
    min_index = i
    for j in range (i + 1, n):
      print("mulai dari (j)",j)
      if data[j] < data[min_index]:
        min_index = j
        print("Hai",min_index)
        print("ini data",data[j])
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
#
# Mulai dari 0
# kalo ini data 64
# mulai dari (j) 0
# mulai dari (j) 1
# Hai 1
# ini data 25
# mulai dari (j) 2
# Hai 2
# ini data 12
# mulai dari (j) 3
# mulai dari (j) 4
# Hai 4
# ini data 11
#
# Mulai dari 1
# kalo ini data 25
# mulai dari (j) 0
# Hai 0
# ini data 11
# mulai dari (j) 1
# mulai dari (j) 2
# mulai dari (j) 3
# mulai dari (j) 4
#
# Mulai dari 2
# kalo ini data 12
# mulai dari (j) 0
# mulai dari (j) 1
# Hai 1
# ini data 11
# mulai dari (j) 2
# mulai dari (j) 3
# mulai dari (j) 4
#
# Mulai dari 3
# kalo ini data 22
# mulai dari (j) 0
# mulai dari (j) 1
# Hai 1
# ini data 12
# mulai dari (j) 2
# Hai 2
# ini data 11
# mulai dari (j) 3
# mulai dari (j) 4
#
# Mulai dari 4
# kalo ini data 64
# mulai dari (j) 0
# Hai 0
# ini data 25
# mulai dari (j) 1
# Hai 1
# ini data 12
# mulai dari (j) 2
# mulai dari (j) 3
# Hai 3
# ini data 11
# mulai dari (j) 4
# Data setelah Selection Sort: [25, 12, 22, 64, 11]

# %% [markdown]
# #Praktikum 03 - Insertion Sort

# %%
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]

# %% [markdown]
# #Praktikum 04 - Studi Kasus Nilai Mahasiswa

# %%
def bubble_sort_nilai(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j][1] < data[j + 1][1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

mahasiswa = [("Andi", 80), ("Budi", 70), ("Cici", 90), ("Doni", 85)]
print("Data sebelum diurutkan:", mahasiswa)
print("Data setelah diurutkan (desc):", bubble_sort_nilai(mahasiswa))
# Out:
# Data sebelum diurutkan: [('Andi', 80), ('Budi', 70), ('Cici', 90), ('Doni', 85)]
# Data setelah diurutkan (desc): [('Cici', 90), ('Doni', 85), ('Andi', 80), ('Budi', 70)]

# %% [markdown]
# #Praktikum 05 - Perbandingan Waktu Eksekusi

# %%
# %%writefile bubble.py

def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] > data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort: ", bubble_sort(angka))
# Out:
# Overwriting bubble.py

# %%
# %%writefile selection.py
def selection_sort(data):
  n = len(data)
  for i in range(n):
    min_index = 1
    for j in range (i + 1, n):
      if data[j] < data[min_index]:
        min_index = j
    data[i], data[min_index] = data[min_index], data[i]
  return data

angka = [64, 25, 12, 22, 11]
print("Data sebelum diurutkan:", angka)
print("Data setelah Selection Sort:", selection_sort(angka))
# Out:
# Overwriting selection.py

# %%
# %%writefile insertion.py
def insertion_sort(data):
  n = len(data)
  for i in range (1, n):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

angka = [12, 11, 13, 5, 6]
print("Data sebelum diurutkan:", angka)
print("Data setelah Insertion Sort:", insertion_sort(angka))
# Out:
# Overwriting insertion.py

# %%
import random, time

from bubble import bubble_sort
from selection import selection_sort
from insertion import insertion_sort

data = [random.randint(1,1000) for i in range(500)]

for func in [bubble_sort, selection_sort, insertion_sort]:
  salinan = data.copy()
  start = time.time()
  func(salinan)
  end = time.time()
  print(f"{func.__name__} membutuhkan waktu {end - start:.5f} detik")
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort:  [11, 12, 22, 25, 34, 64, 90]
# Data sebelum diurutkan: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 64, 12, 25, 22]
# Data sebelum diurutkan: [12, 11, 13, 5, 6]
# Data setelah Insertion Sort: [5, 6, 11, 12, 13]
# bubble_sort membutuhkan waktu 0.01073 detik
# selection_sort membutuhkan waktu 0.00663 detik
# insertion_sort membutuhkan waktu 0.00511 detik

# %% [markdown]
# #Praktikum 06 - Sorting Data Barang

# %%
def bubble_sort_key(data, key_index = 0, reverse = False):
  n = len(data)
  for i in range (n):
    for j in range (0, n - i - 1):
      if reverse:
        if data[j][key_index] < data[j + 1][key_index]:
          data[j], data[j + 1] = data[j + 1], data[j]
  return data

barang = [("Buku", 15000), ("Pensil", 5000), ("Tas", 75000), ("Pulpen", 10000)]
print("Urut berdasarkan nama (asc):", bubble_sort_key(barang.copy(), 0))
print("Urut berdasarkan harga (desc):", bubble_sort_key(barang.copy(), 1, reverse=True))
# Out:
# Urut berdasarkan nama (asc): [('Buku', 15000), ('Pensil', 5000), ('Tas', 75000), ('Pulpen', 10000)]
# Urut berdasarkan harga (desc): [('Tas', 75000), ('Buku', 15000), ('Pulpen', 10000), ('Pensil', 5000)]

# %% [markdown]
# #Penugasan 01 - Eksperimen Bubble Sort

# %%
def bubble_sort(data):
  n = len(data)
  for i in range(n):
    for j in range(0, n - i - 1):
      if data[j] < data[j + 1]:
        data[j], data[j + 1] = data[j + 1], data[j]
  return data

angka = [64, 34, 25, 12, 22, 11, 90]
print("Data sebelum diurutkan: ", angka)
print("Data setelah bubble sort (Descending): ", bubble_sort(angka))
# Out:
# Data sebelum diurutkan:  [64, 34, 25, 12, 22, 11, 90]
# Data setelah bubble sort (Descending):  [90, 64, 34, 25, 22, 12, 11]

# %% [markdown]
# #Penugasan 02 - Eksperimen Selection Sort

# %%
data = [45, 12, 67, 23, 89, 34]
data.sort()
print("Ascending:", data)
data.sort(reverse=True)
print("Descending:", data)
# Out:
# Ascending: [12, 23, 34, 45, 67, 89]
# Descending: [89, 67, 45, 34, 23, 12]

# %% [markdown]
# #Penugasan 03 - Eksperimen Insertion Sort

# %% [markdown]
# #Penugasan 04 - Studi Kasus Tambahan

# %% [markdown]
# #Penugasan 04 - Analisis Kompleksitas

# %% [markdown]
# #Penugasan 04 - Proyek Mini
